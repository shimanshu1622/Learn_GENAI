# %% [markdown]
# # NUMPY

# %% [markdown]
# #### NUmpy is a Fundamental Package for scientific computing in python. It is a pyhton library that provides a multi dimenstional array object and various derived objects such as Masked Arrays or Metrices and an assortment of routines for fast operations on Arrays including Mathematical, Logical, Shape Manipulation, Sorting, Selection, I/O, Discerete Fourier Transform, Basic Liner Algebra, Stastical operations, Random Simulation, etc,
#
# #### AT the core of the Numpy package is the n-dimensional Array object.

# %% [markdown]
# ## WHY NUMPY
#
# ### 2008-2009, Data Science ----> MATLAB, R Language
#
# ### Data Types in Python ----> LIst, Dictionary ---> SLOW
#
# ### Syntax ----> Pyhton --> Easy
#
# ### we need speed and less memory to work with the huge amount of data.
#
# ### Numpy ---> C language ---> Wrapped ---> python
#
# ### Numpy ---> sysntax ---> easy for beginners ---> performing scientific calculations ---> creating multi dimensional arrays ---> speed is faster for applying operations ---> less memory
#
# ### Libraries like Scikit Learn, Tensor Flow and pythorch require input data in Numpy Arrays or Tensors.

# %% [markdown]
# ## NUmpy Arrays VS Python Sequences(list)
#
# #### NUmpy Arrays have fixed size at creation, unlike python lists which grow dynamically. Changing the size of n-dim array will create a new array and delete the original.
#
# #### the elements in numpy array are required to be of the same data type and thus will be of the same size in memory.
#
# #### Numpy arrays facilitata advance mathematical and other types of operations on large number of data, typically, such operations are executed more effeciently with less code than is possible using python lists
